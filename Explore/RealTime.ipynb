# %%
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm
import simpy
import simpy.rt  # Importando o RealtimeEnvironment
import random
from datetime import datetime, timedelta

# %%
# %reload_ext watermark
# %watermark -a "Rodrigo W Pisaia" --iversions --python
# Out:
# Author: Rodrigo W Pisaia
#
# Python implementation: CPython
# Python version       : 3.10.14
# IPython version      : 8.27.0
#
# numpy : 2.1.1
# pandas: 2.2.3
# tqdm  : 4.66.5
# simpy : 4.1.1

# %%
# factory parameters
wood_capacity = 500
initial_wood = 100
electronic_capacity = 200
initial_electronic = 200
pre_paint_capacity = 100
post_paint_capacity = 200
dispatch_capacity = 500

# %%
#statistical
num_body = 2
mean_body = 1
std_body = 0.1

num_neck = 1
mean_neck = 1
std_neck = 0.2

num_paint = 1
mean_paint = 4
std_paint = 0.3

num_ensam = 4
mean_ensam = 1
std_ensam = 0.2

wood_critical_stock = (((8 / mean_body) * num_body + (8 / mean_neck) * num_neck) * 3)
electronic_critical_stock = (8 / mean_ensam) * num_ensam * 2

print(wood_critical_stock)
print(electronic_critical_stock)
# Out:
# 72.0
# 64.0

# %%
class Guitar_Factory:
    def __init__(
        self,
        env,
        wood_capacity,
        initial_wood,
        electronic_capacity,
        initial_electronic,
        pre_paint_capacity,
        post_paint_capacity,
        dispatch_capacity,
        wood_critical_stock,
        electronic_critical_stock,
        dispatch_interval,
    ):
        self.env = env
        self.wood = simpy.Container(env, capacity=wood_capacity, init=initial_wood)
        self.wood_control = env.process(self.wood_stock_control(env))
        self.electronic = simpy.Container(
            env, capacity=electronic_capacity, init=initial_electronic
        )
        self.electronic_control = env.process(self.electronic_stock_control(env))
        self.pre_paint = simpy.Container(env, capacity=pre_paint_capacity, init=0)
        self.post_paint = simpy.Container(env, capacity=post_paint_capacity, init=0)
        self.dispatch = simpy.Container(env, capacity=dispatch_capacity, init=0)
        self.dispatch_interval = dispatch_interval

        env.process(self.dispatch_control(env))

    def wood_stock_control(self, env):
        yield env.timeout(0)
        while True:
            if self.wood.level <= wood_critical_stock:
                print(
                    "wood stock below critical level ({0}) at day {1}, hour {2}".format(
                        self.wood.level, int(env.now / 8), env.now % 8
                    )
                )
                print("calling wood supplier")
                yield env.timeout(16)
                print(
                    "wood supplier arrives at day {0}, hour {1}".format(
                        int(env.now / 8), env.now % 8
                    )
                )
                yield self.wood.put(300)
                print("new wood stock is {0}".format(self.wood.level))
                yield env.timeout(8)
            else:
                yield env.timeout(1)

    def electronic_stock_control(self, env):
        yield env.timeout(0)
        while True:
            if self.electronic.level <= electronic_critical_stock:
                print(
                    "electronic stock below critical level ({0}) at day {1}, hour {2}".format(
                        self.electronic.level, int(env.now / 8), env.now % 8
                    )
                )
                print("calling electronic supplier")
                yield env.timeout(9)
                print(
                    "electronic supplier arrives at day {0}, hour {1}".format(
                        int(env.now / 8), env.now % 8
                    )
                )
                yield self.electronic.put(30)
                print("new electronic stock is {0}".format(self.electronic.level))
                yield env.timeout(8)
            else:
                yield env.timeout(1)

    def dispatch_control(self, env):
        while True:
            # aguarda a  hora de realizar o dispatch
            yield env.timeout(self.dispatch_interval)

            if self.dispatch.level < self.dispatch.capacity:
                yield self.dispatch.put(1)  # Adiciona um item ao dispatch
                print(
                    f"Dispatch realizado em {env.now}: {self.dispatch.level} items no dispatch"
                )
            else:
                print(f"Dispatch cheio em {env.now}: {self.dispatch.level} items")

# %%
def body_maker(env, guitar_factory, logs):
    while True:
        yield guitar_factory.wood.get(1)
        body_time = random.gauss(mean_body, std_body)
        yield env.timeout(body_time)
        guitar_factory.pre_paint.put(1)

        logs.append({
            'time': env.now,
            'event': 'body_made',
            'wood_stock': guitar_factory.wood.level,
            'pre_paint_stock': guitar_factory.pre_paint.level
        })

def neck_maker(env, guitar_factory, logs):
    while True:
        yield guitar_factory.wood.get(1)
        neck_time = random.gauss(mean_neck, std_neck)
        yield env.timeout(neck_time)
        guitar_factory.pre_paint.put(2)

        logs.append({
            'time': env.now,
            'event': 'neck_made',
            'wood_stock': guitar_factory.wood.level,
            'pre_paint_stock': guitar_factory.pre_paint.level
        })

def painter(env, guitar_factory, logs):
    while True:
        yield guitar_factory.pre_paint.get(10)
        paint_time = random.gauss(mean_paint, std_paint)
        yield env.timeout(paint_time)
        guitar_factory.post_paint.put(10)

        logs.append({
            'time': env.now,
            'event': 'painting_done',
            'post_paint_stock': guitar_factory.post_paint.level
        })

def assembler(env, guitar_factory, logs):
    while True:
        yield guitar_factory.post_paint.get(1)
        yield guitar_factory.electronic.get(1)
        assembling_time = max(random.gauss(mean_ensam, std_ensam), 1)
        yield env.timeout(assembling_time)
        guitar_factory.dispatch.put(1)

        logs.append({
            'time': env.now,
            'event': 'guitar_assembled',
            'dispatch_stock': guitar_factory.dispatch.level
        })

# %%
def body_maker_gen(env, guitar_factory, logs):
    for i in range(num_body):
        env.process(body_maker(env, guitar_factory, logs))
        yield env.timeout(0)

def neck_maker_gen(env, guitar_factory, logs):
    for i in range(num_neck):
        env.process(neck_maker(env, guitar_factory, logs))
        yield env.timeout(0)

def painter_maker_gen(env, guitar_factory, logs):
    for i in range(num_paint):
        env.process(painter(env, guitar_factory, logs))
        yield env.timeout(0)

def assembler_maker_gen(env, guitar_factory, logs):
    for i in range(num_ensam):
        env.process(assembler(env, guitar_factory, logs))
        yield env.timeout(0)

# %%
total_time_hours = 40  # Horas
logs = []

factor = 1
env = simpy.rt.RealtimeEnvironment(factor=factor, strict=True)
guitar_factory = Guitar_Factory(env, wood_capacity, initial_wood, electronic_capacity,
                                 initial_electronic, pre_paint_capacity, post_paint_capacity,
                                 dispatch_capacity, wood_critical_stock, electronic_critical_stock, dispatch_interval=10)

# init
body_gen = env.process(body_maker_gen(env, guitar_factory, logs))
neck_gen = env.process(neck_maker_gen(env, guitar_factory, logs))
painter_gen = env.process(painter_maker_gen(env, guitar_factory, logs))
assembler_gen = env.process(assembler_maker_gen(env, guitar_factory, logs))

total_time_hours = 120  # hours
env.run(until=total_time_hours)
# Out:
# wood stock below critical level (71) at day 1, hour 1
# calling wood supplier
# Dispatch realizado em 10: 11 items no dispatch
# Dispatch realizado em 20: 32 items no dispatch
# wood supplier arrives at day 3, hour 1
# new wood stock is 321
# Dispatch realizado em 30: 60 items no dispatch
# Dispatch realizado em 40: 84 items no dispatch
# Dispatch realizado em 50: 115 items no dispatch
# Dispatch realizado em 60: 136 items no dispatch
# electronic stock below critical level (62) at day 7, hour 5
# calling electronic supplier
# electronic supplier arrives at day 8, hour 6
# Dispatch realizado em 70: 165 items no dispatch
# new electronic stock is 70
# electronic stock below critical level (50) at day 9, hour 6
# calling electronic supplier
# Dispatch realizado em 80: 188 items no dispatch
# electronic supplier arrives at day 10, hour 7
# new electronic stock is 60
# Dispatch realizado em 90: 216 items no dispatch
# electronic stock below critical level (40) at day 11, hour 7
# calling electronic supplier
# Dispatch realizado em 100: 240 items no dispatch
# electronic supplier arrives at day 13, hour 0
# new electronic stock is 46
# wood stock below critical level (71) at day 13, hour 5
# calling wood supplier
# Dispatch realizado em 110: 266 items no dispatch
# electronic stock below critical level (30) at day 14, hour 0
# calling electronic supplier

# %%
start_date = datetime(2024, 1, 1)
for log in logs:
    log['time'] = start_date + timedelta(hours=log['time'])

# %%
logs
# Out:
# [{'time': datetime.datetime(2024, 1, 1, 0, 46, 58, 360958),
#   'event': 'neck_made',
#   'wood_stock': 97,
#   'pre_paint_stock': 2},
#  {'time': datetime.datetime(2024, 1, 1, 0, 55, 59, 756361),
#   'event': 'body_made',
#   'wood_stock': 96,
#   'pre_paint_stock': 3},
#  {'time': datetime.datetime(2024, 1, 1, 1, 2, 26, 544242),
#   'event': 'body_made',
#   'wood_stock': 95,
#   'pre_paint_stock': 4},
#  {'time': datetime.datetime(2024, 1, 1, 1, 44, 5, 892271),
#   'event': 'body_made',
#   'wood_stock': 94,
#   'pre_paint_stock': 5},
#  {'time': datetime.datetime(2024, 1, 1, 2, 3, 26, 980102),
#   'event': 'body_made',
#   'wood_stock': 93,
#   'pre_paint_stock': 6},
#  {'time': datetime.datetime(2024, 1, 1, 2, 13, 4, 579983),
#   'event': 'neck_made',
#   'wood_stock': 92,
#   'pre_paint_stock': 8},
#  {'time': datetime.datetime(2024, 1, 1, 2, 40, 28, 551339),
#   'event': 'body_made',
#   'wood_stock': 91,
#   'pre_paint_stock': 9},
#  {'time': datetime.datetime(2024, 1, 1, 2, 52, 16, 712916),
#   'event': 'body_made',
#   'wood_stock': 90,
#   'pre_paint_stock': 10},
#  {'time': datetime.datetime(2024, 1, 1, 3, 25, 36, 651593),
#   'event': 'neck_made',
#   'wood_stock': 89,
#   'pre_paint_stock': 2},
#  {'time': datetime.datetime(2024, 1, 1, 3, 40, 30, 621477),
#   'event': 'body_made',
#   'wood_stock': 88,
#   'pre_paint_stock': 3},
#  {'time': datetime.datetime(2024, 1, 1, 3, 54, 37, 467726),
#   'event': 'body_made',
#   'wood_stock': 87,
#   'pre_paint_stock': 4},
#  {'time': datetime.datetime(2024, 1, 1, 4, 28, 36, 676228),
#   'event': 'body_made',
#   'wood_stock': 86,
#   'pre_paint_stock': 5},
#  {'time': datetime.datetime(2024, 1, 1, 4, 33, 20, 128265),
#   'event': 'neck_made',
#   'wood_stock': 85,
#   'pre_paint_stock': 7},
#  {'time': datetime.datetime(2024, 1, 1, 4, 52, 15, 919352),
#   'event': 'body_made',
#   'wood_stock': 84,
#   'pre_paint_stock': 8},
#  {'time': datetime.datetime(2024, 1, 1, 5, 29, 55, 349415),
#   'event': 'body_made',
#   'wood_stock': 83,
#   'pre_paint_stock': 9},
#  {'time': datetime.datetime(2024, 1, 1, 5, 37, 3, 909405),
#   'event': 'neck_made',
#   'wood_stock': 82,
#   'pre_paint_stock': 11},
#  {'time': datetime.datetime(2024, 1, 1, 5, 54, 9, 90418),
#   'event': 'body_made',
#   'wood_stock': 81,
#   'pre_paint_stock': 12},
#  {'time': datetime.datetime(2024, 1, 1, 6, 22, 26, 422565),
#   'event': 'neck_made',
#   'wood_stock': 80,
#   'pre_paint_stock': 14},
#  {'time': datetime.datetime(2024, 1, 1, 6, 33, 39, 359526),
#   'event': 'body_made',
#   'wood_stock': 79,
#   'pre_paint_stock': 15},
#  {'time': datetime.datetime(2024, 1, 1, 6, 43, 27, 848538),
#   'event': 'painting_done',
#   'post_paint_stock': 10},
#  {'time': datetime.datetime(2024, 1, 1, 6, 55, 8, 130622),
#   'event': 'body_made',
#   'wood_stock': 78,
#   'pre_paint_stock': 6},
#  {'time': datetime.datetime(2024, 1, 1, 7, 24, 23, 830498),
#   'event': 'neck_made',
#   'wood_stock': 77,
#   'pre_paint_stock': 8},
#  {'time': datetime.datetime(2024, 1, 1, 7, 36, 38, 468872),
#   'event': 'body_made',
#   'wood_stock': 76,
#   'pre_paint_stock': 9},
#  {'time': datetime.datetime(2024, 1, 1, 7, 43, 27, 848538),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 1},
#  {'time': datetime.datetime(2024, 1, 1, 7, 43, 47, 393209),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 2},
#  {'time': datetime.datetime(2024, 1, 1, 7, 50, 22, 563755),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 3},
#  {'time': datetime.datetime(2024, 1, 1, 7, 50, 43, 54218),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 4},
#  {'time': datetime.datetime(2024, 1, 1, 7, 52, 9, 382880),
#   'event': 'body_made',
#   'wood_stock': 75,
#   'pre_paint_stock': 10},
#  {'time': datetime.datetime(2024, 1, 1, 8, 2, 43, 546797),
#   'event': 'neck_made',
#   'wood_stock': 74,
#   'pre_paint_stock': 12},
#  {'time': datetime.datetime(2024, 1, 1, 8, 35, 15, 98493),
#   'event': 'body_made',
#   'wood_stock': 73,
#   'pre_paint_stock': 13},
#  {'time': datetime.datetime(2024, 1, 1, 8, 43, 27, 848538),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 5},
#  {'time': datetime.datetime(2024, 1, 1, 8, 43, 47, 393209),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 6},
#  {'time': datetime.datetime(2024, 1, 1, 8, 50, 43, 54218),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 7},
#  {'time': datetime.datetime(2024, 1, 1, 8, 57, 59, 989282),
#   'event': 'body_made',
#   'wood_stock': 72,
#   'pre_paint_stock': 14},
#  {'time': datetime.datetime(2024, 1, 1, 8, 58, 44, 195493),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 8},
#  {'time': datetime.datetime(2024, 1, 1, 9, 19, 0, 434583),
#   'event': 'neck_made',
#   'wood_stock': 71,
#   'pre_paint_stock': 16},
#  {'time': datetime.datetime(2024, 1, 1, 9, 26, 45, 585274),
#   'event': 'body_made',
#   'wood_stock': 70,
#   'pre_paint_stock': 17},
#  {'time': datetime.datetime(2024, 1, 1, 9, 49, 53, 84102),
#   'event': 'body_made',
#   'wood_stock': 69,
#   'pre_paint_stock': 18},
#  {'time': datetime.datetime(2024, 1, 1, 9, 52, 16, 334554),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 9},
#  {'time': datetime.datetime(2024, 1, 1, 9, 54, 57, 422000),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 10},
#  {'time': datetime.datetime(2024, 1, 1, 10, 17, 9, 65233),
#   'event': 'body_made',
#   'wood_stock': 68,
#   'pre_paint_stock': 19},
#  {'time': datetime.datetime(2024, 1, 1, 10, 30, 42, 830481),
#   'event': 'neck_made',
#   'wood_stock': 67,
#   'pre_paint_stock': 21},
#  {'time': datetime.datetime(2024, 1, 1, 10, 52, 40, 100592),
#   'event': 'body_made',
#   'wood_stock': 66,
#   'pre_paint_stock': 22},
#  {'time': datetime.datetime(2024, 1, 1, 11, 9, 33, 267240),
#   'event': 'body_made',
#   'wood_stock': 65,
#   'pre_paint_stock': 23},
#  {'time': datetime.datetime(2024, 1, 1, 11, 10, 28, 165316),
#   'event': 'painting_done',
#   'post_paint_stock': 10},
#  {'time': datetime.datetime(2024, 1, 1, 11, 21, 54, 497834),
#   'event': 'neck_made',
#   'wood_stock': 64,
#   'pre_paint_stock': 15},
#  {'time': datetime.datetime(2024, 1, 1, 11, 55, 49, 723582),
#   'event': 'body_made',
#   'wood_stock': 63,
#   'pre_paint_stock': 16},
#  {'time': datetime.datetime(2024, 1, 1, 12, 0, 55, 466683),
#   'event': 'body_made',
#   'wood_stock': 62,
#   'pre_paint_stock': 17},
#  {'time': datetime.datetime(2024, 1, 1, 12, 10, 28, 165316),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 12},
#  {'time': datetime.datetime(2024, 1, 1, 12, 10, 28, 165316),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 13},
#  {'time': datetime.datetime(2024, 1, 1, 12, 10, 28, 165316),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 14},
#  {'time': datetime.datetime(2024, 1, 1, 12, 14, 18, 225347),
#   'event': 'neck_made',
#   'wood_stock': 61,
#   'pre_paint_stock': 19},
#  {'time': datetime.datetime(2024, 1, 1, 12, 32, 56, 716582),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 15},
#  {'time': datetime.datetime(2024, 1, 1, 12, 49, 9, 163378),
#   'event': 'body_made',
#   'wood_stock': 60,
#   'pre_paint_stock': 20},
#  {'time': datetime.datetime(2024, 1, 1, 13, 10, 17, 373187),
#   'event': 'body_made',
#   'wood_stock': 59,
#   'pre_paint_stock': 21},
#  {'time': datetime.datetime(2024, 1, 1, 13, 10, 21, 816516),
#   'event': 'neck_made',
#   'wood_stock': 58,
#   'pre_paint_stock': 23},
#  {'time': datetime.datetime(2024, 1, 1, 13, 10, 28, 165316),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 16},
#  {'time': datetime.datetime(2024, 1, 1, 13, 10, 28, 165316),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 17},
#  {'time': datetime.datetime(2024, 1, 1, 13, 17, 12, 16239),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 18},
#  {'time': datetime.datetime(2024, 1, 1, 13, 32, 56, 716582),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 19},
#  {'time': datetime.datetime(2024, 1, 1, 13, 53, 13, 92271),
#   'event': 'body_made',
#   'wood_stock': 57,
#   'pre_paint_stock': 24},
#  {'time': datetime.datetime(2024, 1, 1, 14, 1, 15, 900248),
#   'event': 'body_made',
#   'wood_stock': 56,
#   'pre_paint_stock': 25},
#  {'time': datetime.datetime(2024, 1, 1, 14, 10, 28, 165316),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 20},
#  {'time': datetime.datetime(2024, 1, 1, 14, 14, 31, 930598),
#   'event': 'neck_made',
#   'wood_stock': 55,
#   'pre_paint_stock': 27},
#  {'time': datetime.datetime(2024, 1, 1, 14, 32, 24, 483498),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 21},
#  {'time': datetime.datetime(2024, 1, 1, 14, 49, 22, 897214),
#   'event': 'body_made',
#   'wood_stock': 54,
#   'pre_paint_stock': 28},
#  {'time': datetime.datetime(2024, 1, 1, 15, 9, 39, 463293),
#   'event': 'body_made',
#   'wood_stock': 53,
#   'pre_paint_stock': 29},
#  {'time': datetime.datetime(2024, 1, 1, 15, 27, 22, 886355),
#   'event': 'neck_made',
#   'wood_stock': 52,
#   'pre_paint_stock': 31},
#  {'time': datetime.datetime(2024, 1, 1, 15, 36, 10, 372339),
#   'event': 'painting_done',
#   'post_paint_stock': 10},
#  {'time': datetime.datetime(2024, 1, 1, 15, 43, 58, 536989),
#   'event': 'body_made',
#   'wood_stock': 51,
#   'pre_paint_stock': 22},
#  {'time': datetime.datetime(2024, 1, 1, 16, 10, 27, 80423),
#   'event': 'body_made',
#   'wood_stock': 50,
#   'pre_paint_stock': 23},
#  {'time': datetime.datetime(2024, 1, 1, 16, 36, 10, 372339),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 22},
#  {'time': datetime.datetime(2024, 1, 1, 16, 36, 10, 372339),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 23},
#  {'time': datetime.datetime(2024, 1, 1, 16, 36, 33, 397824),
#   'event': 'body_made',
#   'wood_stock': 49,
#   'pre_paint_stock': 24},
#  {'time': datetime.datetime(2024, 1, 1, 16, 37, 8, 932983),
#   'event': 'neck_made',
#   'wood_stock': 48,
#   'pre_paint_stock': 26},
#  {'time': datetime.datetime(2024, 1, 1, 16, 42, 12, 173131),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 24},
#  {'time': datetime.datetime(2024, 1, 1, 16, 43, 5, 136657),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 25},
#  {'time': datetime.datetime(2024, 1, 1, 17, 11, 3, 769418),
#   'event': 'body_made',
#   'wood_stock': 47,
#   'pre_paint_stock': 27},
#  {'time': datetime.datetime(2024, 1, 1, 17, 25, 45, 645745),
#   'event': 'neck_made',
#   'wood_stock': 46,
#   'pre_paint_stock': 29},
#  {'time': datetime.datetime(2024, 1, 1, 17, 36, 10, 372339),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 26},
#  {'time': datetime.datetime(2024, 1, 1, 17, 36, 10, 372339),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 27},
#  {'time': datetime.datetime(2024, 1, 1, 17, 42, 10, 717953),
#   'event': 'body_made',
#   'wood_stock': 45,
#   'pre_paint_stock': 30},
#  {'time': datetime.datetime(2024, 1, 1, 17, 45, 11, 97254),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 28},
#  {'time': datetime.datetime(2024, 1, 1, 17, 48, 29, 445813),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 29},
#  {'time': datetime.datetime(2024, 1, 1, 18, 0, 43, 187974),
#   'event': 'body_made',
#   'wood_stock': 44,
#   'pre_paint_stock': 31},
#  {'time': datetime.datetime(2024, 1, 1, 18, 28, 13, 880660),
#   'event': 'neck_made',
#   'wood_stock': 43,
#   'pre_paint_stock': 33},
#  {'time': datetime.datetime(2024, 1, 1, 18, 36, 10, 372339),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 30},
#  {'time': datetime.datetime(2024, 1, 1, 18, 40, 22, 953473),
#   'event': 'body_made',
#   'wood_stock': 42,
#   'pre_paint_stock': 34},
#  {'time': datetime.datetime(2024, 1, 1, 19, 2, 6, 33697),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 31},
#  {'time': datetime.datetime(2024, 1, 1, 19, 4, 9, 44729),
#   'event': 'body_made',
#   'wood_stock': 41,
#   'pre_paint_stock': 35},
#  {'time': datetime.datetime(2024, 1, 1, 19, 24, 33, 16027),
#   'event': 'painting_done',
#   'post_paint_stock': 10},
#  {'time': datetime.datetime(2024, 1, 1, 19, 25, 23, 482647),
#   'event': 'neck_made',
#   'wood_stock': 40,
#   'pre_paint_stock': 27},
#  {'time': datetime.datetime(2024, 1, 1, 19, 40, 0, 515988),
#   'event': 'body_made',
#   'wood_stock': 39,
#   'pre_paint_stock': 28},
#  {'time': datetime.datetime(2024, 1, 1, 20, 15, 42, 39896),
#   'event': 'body_made',
#   'wood_stock': 38,
#   'pre_paint_stock': 29},
#  {'time': datetime.datetime(2024, 1, 1, 20, 24, 33, 16027),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 33},
#  {'time': datetime.datetime(2024, 1, 1, 20, 24, 48, 524129),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 34},
#  {'time': datetime.datetime(2024, 1, 1, 20, 30, 3, 368094),
#   'event': 'neck_made',
#   'wood_stock': 37,
#   'pre_paint_stock': 31},
#  {'time': datetime.datetime(2024, 1, 1, 20, 31, 38, 879768),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 35},
#  {'time': datetime.datetime(2024, 1, 1, 20, 32, 17, 215125),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 36},
#  {'time': datetime.datetime(2024, 1, 1, 20, 44, 16, 114498),
#   'event': 'body_made',
#   'wood_stock': 36,
#   'pre_paint_stock': 32},
#  {'time': datetime.datetime(2024, 1, 1, 21, 17, 10, 552765),
#   'event': 'body_made',
#   'wood_stock': 35,
#   'pre_paint_stock': 33},
#  {'time': datetime.datetime(2024, 1, 1, 21, 24, 33, 16027),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 37},
#  {'time': datetime.datetime(2024, 1, 1, 21, 25, 54, 628441),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 38},
#  {'time': datetime.datetime(2024, 1, 1, 21, 31, 38, 879768),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 39},
#  {'time': datetime.datetime(2024, 1, 1, 21, 32, 17, 215125),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 40},
#  {'time': datetime.datetime(2024, 1, 1, 21, 41, 10, 228858),
#   'event': 'neck_made',
#   'wood_stock': 34,
#   'pre_paint_stock': 35},
#  {'time': datetime.datetime(2024, 1, 1, 21, 45, 5, 17837),
#   'event': 'body_made',
#   'wood_stock': 33,
#   'pre_paint_stock': 36},
#  {'time': datetime.datetime(2024, 1, 1, 22, 5, 14, 152607),
#   'event': 'body_made',
#   'wood_stock': 32,
#   'pre_paint_stock': 37},
#  {'time': datetime.datetime(2024, 1, 1, 22, 24, 33, 16027),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 41},
#  {'time': datetime.datetime(2024, 1, 1, 22, 26, 31, 981798),
#   'event': 'neck_made',
#   'wood_stock': 31,
#   'pre_paint_stock': 39},
#  {'time': datetime.datetime(2024, 1, 1, 22, 30, 36, 371891),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 42},
#  {'time': datetime.datetime(2024, 1, 1, 22, 42, 51, 911596),
#   'event': 'body_made',
#   'wood_stock': 30,
#   'pre_paint_stock': 40},
#  {'time': datetime.datetime(2024, 1, 1, 22, 59, 17, 840947),
#   'event': 'body_made',
#   'wood_stock': 29,
#   'pre_paint_stock': 41},
#  {'time': datetime.datetime(2024, 1, 1, 23, 36, 21, 787748),
#   'event': 'body_made',
#   'wood_stock': 28,
#   'pre_paint_stock': 42},
#  {'time': datetime.datetime(2024, 1, 1, 23, 38, 52, 20684),
#   'event': 'painting_done',
#   'post_paint_stock': 10},
#  {'time': datetime.datetime(2024, 1, 1, 23, 40, 52, 322823),
#   'event': 'neck_made',
#   'wood_stock': 27,
#   'pre_paint_stock': 34},
#  {'time': datetime.datetime(2024, 1, 1, 23, 56, 40, 953894),
#   'event': 'body_made',
#   'wood_stock': 26,
#   'pre_paint_stock': 35},
#  {'time': datetime.datetime(2024, 1, 2, 0, 23, 32, 309306),
#   'event': 'neck_made',
#   'wood_stock': 25,
#   'pre_paint_stock': 37},
#  {'time': datetime.datetime(2024, 1, 2, 0, 38, 40, 212624),
#   'event': 'body_made',
#   'wood_stock': 24,
#   'pre_paint_stock': 38},
#  {'time': datetime.datetime(2024, 1, 2, 0, 38, 52, 20684),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 43},
#  {'time': datetime.datetime(2024, 1, 2, 0, 41, 37, 190174),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 44},
#  {'time': datetime.datetime(2024, 1, 2, 0, 44, 46, 525049),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 45},
#  {'time': datetime.datetime(2024, 1, 2, 0, 58, 8, 552134),
#   'event': 'body_made',
#   'wood_stock': 23,
#   'pre_paint_stock': 39},
#  {'time': datetime.datetime(2024, 1, 2, 0, 59, 11, 842622),
#   'event': 'neck_made',
#   'wood_stock': 22,
#   'pre_paint_stock': 41},
#  {'time': datetime.datetime(2024, 1, 2, 1, 2, 53, 600232),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 46},
#  {'time': datetime.datetime(2024, 1, 2, 1, 33, 54, 260248),
#   'event': 'body_made',
#   'wood_stock': 321,
#   'pre_paint_stock': 42},
#  {'time': datetime.datetime(2024, 1, 2, 1, 38, 52, 20684),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 47},
#  {'time': datetime.datetime(2024, 1, 2, 1, 41, 37, 190174),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 48},
#  {'time': datetime.datetime(2024, 1, 2, 1, 44, 46, 525049),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 49},
#  {'time': datetime.datetime(2024, 1, 2, 1, 57, 12, 954103),
#   'event': 'body_made',
#   'wood_stock': 320,
#   'pre_paint_stock': 43},
#  {'time': datetime.datetime(2024, 1, 2, 2, 11, 3, 662887),
#   'event': 'neck_made',
#   'wood_stock': 319,
#   'pre_paint_stock': 45},
#  {'time': datetime.datetime(2024, 1, 2, 2, 12, 22, 67491),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 50},
#  {'time': datetime.datetime(2024, 1, 2, 2, 33, 55, 188554),
#   'event': 'body_made',
#   'wood_stock': 318,
#   'pre_paint_stock': 46},
#  {'time': datetime.datetime(2024, 1, 2, 2, 42, 25, 120599),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 51},
#  {'time': datetime.datetime(2024, 1, 2, 2, 46, 41, 758284),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 52},
#  {'time': datetime.datetime(2024, 1, 2, 2, 55, 52, 774555),
#   'event': 'body_made',
#   'wood_stock': 317,
#   'pre_paint_stock': 47},
#  {'time': datetime.datetime(2024, 1, 2, 3, 17, 45, 844070),
#   'event': 'neck_made',
#   'wood_stock': 316,
#   'pre_paint_stock': 49},
#  {'time': datetime.datetime(2024, 1, 2, 3, 18, 4, 162121),
#   'event': 'body_made',
#   'wood_stock': 315,
#   'pre_paint_stock': 50},
#  {'time': datetime.datetime(2024, 1, 2, 3, 42, 58, 607346),
#   'event': 'painting_done',
#   'post_paint_stock': 10},
#  {'time': datetime.datetime(2024, 1, 2, 3, 57, 48, 610722),
#   'event': 'neck_made',
#   'wood_stock': 314,
#   'pre_paint_stock': 42},
#  {'time': datetime.datetime(2024, 1, 2, 4, 1, 11, 844341),
#   'event': 'body_made',
#   'wood_stock': 313,
#   'pre_paint_stock': 43},
#  {'time': datetime.datetime(2024, 1, 2, 4, 10, 44, 175724),
#   'event': 'body_made',
#   'wood_stock': 312,
#   'pre_paint_stock': 44},
#  {'time': datetime.datetime(2024, 1, 2, 4, 42, 58, 607346),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 53},
#  {'time': datetime.datetime(2024, 1, 2, 4, 42, 58, 607346),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 54},
#  {'time': datetime.datetime(2024, 1, 2, 4, 42, 58, 607346),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 55},
#  {'time': datetime.datetime(2024, 1, 2, 4, 47, 32, 780642),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 56},
#  {'time': datetime.datetime(2024, 1, 2, 4, 53, 27, 677023),
#   'event': 'neck_made',
#   'wood_stock': 311,
#   'pre_paint_stock': 46},
#  {'time': datetime.datetime(2024, 1, 2, 5, 0, 48, 268713),
#   'event': 'body_made',
#   'wood_stock': 310,
#   'pre_paint_stock': 47},
#  {'time': datetime.datetime(2024, 1, 2, 5, 5, 1, 573346),
#   'event': 'body_made',
#   'wood_stock': 309,
#   'pre_paint_stock': 48},
#  {'time': datetime.datetime(2024, 1, 2, 5, 28, 9, 702450),
#   'event': 'neck_made',
#   'wood_stock': 308,
#   'pre_paint_stock': 50},
#  {'time': datetime.datetime(2024, 1, 2, 5, 42, 58, 607346),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 57},
#  {'time': datetime.datetime(2024, 1, 2, 5, 42, 58, 607346),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 58},
#  {'time': datetime.datetime(2024, 1, 2, 5, 57, 7, 463218),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 59},
#  {'time': datetime.datetime(2024, 1, 2, 5, 58, 17, 316804),
#   'event': 'body_made',
#   'wood_stock': 307,
#   'pre_paint_stock': 51},
#  {'time': datetime.datetime(2024, 1, 2, 6, 5, 17, 532482),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 61},
#  {'time': datetime.datetime(2024, 1, 2, 6, 9, 41, 803153),
#   'event': 'neck_made',
#   'wood_stock': 306,
#   'pre_paint_stock': 53},
#  {'time': datetime.datetime(2024, 1, 2, 6, 14, 3, 360901),
#   'event': 'body_made',
#   'wood_stock': 305,
#   'pre_paint_stock': 54},
#  {'time': datetime.datetime(2024, 1, 2, 6, 42, 58, 607346),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 62},
#  {'time': datetime.datetime(2024, 1, 2, 6, 48, 37, 322030),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 63},
#  {'time': datetime.datetime(2024, 1, 2, 6, 54, 35, 576089),
#   'event': 'body_made',
#   'wood_stock': 304,
#   'pre_paint_stock': 55},
#  {'time': datetime.datetime(2024, 1, 2, 7, 5, 8, 200827),
#   'event': 'painting_done',
#   'post_paint_stock': 10},
#  {'time': datetime.datetime(2024, 1, 2, 7, 11, 20, 90598),
#   'event': 'neck_made',
#   'wood_stock': 303,
#   'pre_paint_stock': 47},
#  {'time': datetime.datetime(2024, 1, 2, 7, 12, 21, 510276),
#   'event': 'body_made',
#   'wood_stock': 302,
#   'pre_paint_stock': 48},
#  {'time': datetime.datetime(2024, 1, 2, 7, 56, 59, 211011),
#   'event': 'body_made',
#   'wood_stock': 301,
#   'pre_paint_stock': 49},
#  {'time': datetime.datetime(2024, 1, 2, 8, 0, 43, 188424),
#   'event': 'neck_made',
#   'wood_stock': 300,
#   'pre_paint_stock': 51},
#  {'time': datetime.datetime(2024, 1, 2, 8, 5, 8, 200827),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 64},
#  {'time': datetime.datetime(2024, 1, 2, 8, 5, 8, 200827),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 65},
#  {'time': datetime.datetime(2024, 1, 2, 8, 5, 29, 37918),
#   'event': 'body_made',
#   'wood_stock': 299,
#   'pre_paint_stock': 52},
#  {'time': datetime.datetime(2024, 1, 2, 8, 7, 34, 914309),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 66},
#  {'time': datetime.datetime(2024, 1, 2, 8, 16, 31, 263768),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 67},
#  {'time': datetime.datetime(2024, 1, 2, 8, 53, 43, 794233),
#   'event': 'body_made',
#   'wood_stock': 298,
#   'pre_paint_stock': 53},
#  {'time': datetime.datetime(2024, 1, 2, 9, 4, 41, 69980),
#   'event': 'body_made',
#   'wood_stock': 297,
#   'pre_paint_stock': 54},
#  {'time': datetime.datetime(2024, 1, 2, 9, 7, 34, 914309),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 68},
#  {'time': datetime.datetime(2024, 1, 2, 9, 15, 6, 674384),
#   'event': 'neck_made',
#   'wood_stock': 296,
#   'pre_paint_stock': 56},
#  {'time': datetime.datetime(2024, 1, 2, 9, 16, 31, 263768),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 69},
#  {'time': datetime.datetime(2024, 1, 2, 9, 16, 54, 175596),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 70},
#  {'time': datetime.datetime(2024, 1, 2, 9, 34, 44, 304377),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 71},
#  {'time': datetime.datetime(2024, 1, 2, 9, 49, 31, 350455),
#   'event': 'body_made',
#   'wood_stock': 295,
#   'pre_paint_stock': 57},
#  {'time': datetime.datetime(2024, 1, 2, 10, 13, 42, 126372),
#   'event': 'body_made',
#   'wood_stock': 294,
#   'pre_paint_stock': 58},
#  {'time': datetime.datetime(2024, 1, 2, 10, 16, 31, 263768),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 72},
#  {'time': datetime.datetime(2024, 1, 2, 10, 19, 40, 446986),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 73},
#  {'time': datetime.datetime(2024, 1, 2, 10, 26, 52, 848543),
#   'event': 'neck_made',
#   'wood_stock': 293,
#   'pre_paint_stock': 60},
#  {'time': datetime.datetime(2024, 1, 2, 10, 49, 33, 136299),
#   'event': 'body_made',
#   'wood_stock': 292,
#   'pre_paint_stock': 61},
#  {'time': datetime.datetime(2024, 1, 2, 11, 14, 38, 321746),
#   'event': 'body_made',
#   'wood_stock': 291,
#   'pre_paint_stock': 62},
#  {'time': datetime.datetime(2024, 1, 2, 11, 18, 41, 457882),
#   'event': 'neck_made',
#   'wood_stock': 290,
#   'pre_paint_stock': 64},
#  {'time': datetime.datetime(2024, 1, 2, 11, 24, 34, 581682),
#   'event': 'painting_done',
#   'post_paint_stock': 10},
#  {'time': datetime.datetime(2024, 1, 2, 11, 34, 40, 800321),
#   'event': 'body_made',
#   'wood_stock': 289,
#   'pre_paint_stock': 55},
#  {'time': datetime.datetime(2024, 1, 2, 12, 8, 42, 542606),
#   'event': 'body_made',
#   'wood_stock': 288,
#   'pre_paint_stock': 56},
#  {'time': datetime.datetime(2024, 1, 2, 12, 24, 34, 581682),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 74},
#  {'time': datetime.datetime(2024, 1, 2, 12, 24, 34, 581682),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 75},
#  {'time': datetime.datetime(2024, 1, 2, 12, 29, 11, 554012),
#   'event': 'neck_made',
#   'wood_stock': 287,
#   'pre_paint_stock': 58},
#  {'time': datetime.datetime(2024, 1, 2, 12, 33, 10, 994451),
#   'event': 'body_made',
#   'wood_stock': 286,
#   'pre_paint_stock': 59},
#  {'time': datetime.datetime(2024, 1, 2, 12, 35, 31, 113221),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 76},
#  {'time': datetime.datetime(2024, 1, 2, 12, 39, 47, 6251),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 77},
#  {'time': datetime.datetime(2024, 1, 2, 13, 9, 18, 292622),
#   'event': 'body_made',
#   'wood_stock': 285,
#   'pre_paint_stock': 60},
#  {'time': datetime.datetime(2024, 1, 2, 13, 25, 49, 509814),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 78},
#  {'time': datetime.datetime(2024, 1, 2, 13, 28, 30, 579170),
#   'event': 'body_made',
#   'wood_stock': 284,
#   'pre_paint_stock': 61},
#  {'time': datetime.datetime(2024, 1, 2, 13, 37, 41, 283925),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 79},
#  {'time': datetime.datetime(2024, 1, 2, 13, 38, 56, 78762),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 80},
#  {'time': datetime.datetime(2024, 1, 2, 13, 39, 47, 6251),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 81},
#  {'time': datetime.datetime(2024, 1, 2, 13, 44, 48, 537353),
#   'event': 'neck_made',
#   'wood_stock': 283,
#   'pre_paint_stock': 63},
#  {'time': datetime.datetime(2024, 1, 2, 14, 8, 9, 135031),
#   'event': 'body_made',
#   'wood_stock': 282,
#   'pre_paint_stock': 64},
#  {'time': datetime.datetime(2024, 1, 2, 14, 25, 49, 509814),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 82},
#  {'time': datetime.datetime(2024, 1, 2, 14, 32, 1, 432013),
#   'event': 'body_made',
#   'wood_stock': 281,
#   'pre_paint_stock': 65},
#  {'time': datetime.datetime(2024, 1, 2, 14, 37, 41, 283925),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 83},
#  {'time': datetime.datetime(2024, 1, 2, 14, 57, 53, 538575),
#   'event': 'neck_made',
#   'wood_stock': 280,
#   'pre_paint_stock': 67},
#  {'time': datetime.datetime(2024, 1, 2, 15, 8, 40, 743764),
#   'event': 'body_made',
#   'wood_stock': 279,
#   'pre_paint_stock': 68},
#  {'time': datetime.datetime(2024, 1, 2, 15, 9, 40, 425210),
#   'event': 'painting_done',
#   'post_paint_stock': 10},
#  {'time': datetime.datetime(2024, 1, 2, 15, 39, 34, 278071),
#   'event': 'body_made',
#   'wood_stock': 278,
#   'pre_paint_stock': 59},
#  {'time': datetime.datetime(2024, 1, 2, 15, 58, 54, 846641),
#   'event': 'neck_made',
#   'wood_stock': 277,
#   'pre_paint_stock': 61},
#  {'time': datetime.datetime(2024, 1, 2, 16, 8, 17, 626033),
#   'event': 'body_made',
#   'wood_stock': 276,
#   'pre_paint_stock': 62},
#  {'time': datetime.datetime(2024, 1, 2, 16, 9, 40, 425210),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 85},
#  {'time': datetime.datetime(2024, 1, 2, 16, 9, 40, 425210),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 86},
#  {'time': datetime.datetime(2024, 1, 2, 16, 9, 40, 425210),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 87},
#  {'time': datetime.datetime(2024, 1, 2, 16, 33, 7, 921271),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 88},
#  {'time': datetime.datetime(2024, 1, 2, 16, 44, 15, 14659),
#   'event': 'body_made',
#   'wood_stock': 275,
#   'pre_paint_stock': 63},
#  {'time': datetime.datetime(2024, 1, 2, 17, 2, 25, 547977),
#   'event': 'neck_made',
#   'wood_stock': 274,
#   'pre_paint_stock': 65},
#  {'time': datetime.datetime(2024, 1, 2, 17, 3, 6, 992658),
#   'event': 'body_made',
#   'wood_stock': 273,
#   'pre_paint_stock': 66},
#  {'time': datetime.datetime(2024, 1, 2, 17, 9, 40, 425210),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 89},
#  {'time': datetime.datetime(2024, 1, 2, 17, 11, 37, 331242),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 90},
#  {'time': datetime.datetime(2024, 1, 2, 17, 13, 23, 313531),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 91},
#  {'time': datetime.datetime(2024, 1, 2, 17, 33, 7, 921271),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 92},
#  {'time': datetime.datetime(2024, 1, 2, 17, 34, 3, 889633),
#   'event': 'body_made',
#   'wood_stock': 272,
#   'pre_paint_stock': 67},
#  {'time': datetime.datetime(2024, 1, 2, 18, 5, 35, 684882),
#   'event': 'body_made',
#   'wood_stock': 271,
#   'pre_paint_stock': 68},
#  {'time': datetime.datetime(2024, 1, 2, 18, 10, 2, 185109),
#   'event': 'neck_made',
#   'wood_stock': 270,
#   'pre_paint_stock': 70},
#  {'time': datetime.datetime(2024, 1, 2, 18, 11, 37, 331242),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 93},
#  {'time': datetime.datetime(2024, 1, 2, 18, 18, 19, 17192),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 94},
#  {'time': datetime.datetime(2024, 1, 2, 18, 35, 7, 887573),
#   'event': 'body_made',
#   'wood_stock': 269,
#   'pre_paint_stock': 71},
#  {'time': datetime.datetime(2024, 1, 2, 18, 42, 40, 384620),
#   'event': 'painting_done',
#   'post_paint_stock': 10},
#  {'time': datetime.datetime(2024, 1, 2, 19, 1, 40, 456192),
#   'event': 'body_made',
#   'wood_stock': 268,
#   'pre_paint_stock': 62},
#  {'time': datetime.datetime(2024, 1, 2, 19, 2, 46, 507828),
#   'event': 'neck_made',
#   'wood_stock': 267,
#   'pre_paint_stock': 64},
#  {'time': datetime.datetime(2024, 1, 2, 19, 29, 30, 720224),
#   'event': 'body_made',
#   'wood_stock': 266,
#   'pre_paint_stock': 65},
#  {'time': datetime.datetime(2024, 1, 2, 19, 42, 40, 384620),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 95},
#  {'time': datetime.datetime(2024, 1, 2, 19, 42, 40, 384620),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 96},
#  {'time': datetime.datetime(2024, 1, 2, 19, 49, 47, 502035),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 97},
#  {'time': datetime.datetime(2024, 1, 2, 19, 55, 50, 51737),
#   'event': 'body_made',
#   'wood_stock': 265,
#   'pre_paint_stock': 66},
#  {'time': datetime.datetime(2024, 1, 2, 19, 56, 48, 440862),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 98},
#  {'time': datetime.datetime(2024, 1, 2, 19, 59, 53, 374872),
#   'event': 'neck_made',
#   'wood_stock': 264,
#   'pre_paint_stock': 68},
#  {'time': datetime.datetime(2024, 1, 2, 20, 21, 56, 323279),
#   'event': 'body_made',
#   'wood_stock': 263,
#   'pre_paint_stock': 69},
#  {'time': datetime.datetime(2024, 1, 2, 20, 42, 40, 384620),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 99},
#  {'time': datetime.datetime(2024, 1, 2, 20, 42, 40, 384620),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 100},
#  {'time': datetime.datetime(2024, 1, 2, 20, 48, 34, 676939),
#   'event': 'body_made',
#   'wood_stock': 262,
#   'pre_paint_stock': 70},
#  {'time': datetime.datetime(2024, 1, 2, 20, 49, 47, 502035),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 101},
#  {'time': datetime.datetime(2024, 1, 2, 20, 56, 48, 440862),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 102},
#  {'time': datetime.datetime(2024, 1, 2, 21, 21, 11, 312428),
#   'event': 'neck_made',
#   'wood_stock': 261,
#   'pre_paint_stock': 72},
#  {'time': datetime.datetime(2024, 1, 2, 21, 21, 34, 657030),
#   'event': 'body_made',
#   'wood_stock': 260,
#   'pre_paint_stock': 73},
#  {'time': datetime.datetime(2024, 1, 2, 21, 44, 21, 458424),
#   'event': 'body_made',
#   'wood_stock': 259,
#   'pre_paint_stock': 74},
#  {'time': datetime.datetime(2024, 1, 2, 21, 51, 18, 730618),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 103},
#  {'time': datetime.datetime(2024, 1, 2, 21, 53, 51, 692963),
#   'event': 'neck_made',
#   'wood_stock': 258,
#   'pre_paint_stock': 76},
#  {'time': datetime.datetime(2024, 1, 2, 21, 55, 54, 141062),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 104},
#  {'time': datetime.datetime(2024, 1, 2, 22, 21, 34, 112503),
#   'event': 'body_made',
#   'wood_stock': 257,
#   'pre_paint_stock': 77},
#  {'time': datetime.datetime(2024, 1, 2, 22, 30, 19, 690791),
#   'event': 'painting_done',
#   'post_paint_stock': 10},
#  {'time': datetime.datetime(2024, 1, 2, 22, 40, 17, 881818),
#   'event': 'body_made',
#   'wood_stock': 256,
#   'pre_paint_stock': 68},
#  {'time': datetime.datetime(2024, 1, 2, 23, 17, 44, 899431),
#   'event': 'neck_made',
#   'wood_stock': 255,
#   'pre_paint_stock': 70},
#  {'time': datetime.datetime(2024, 1, 2, 23, 30, 19, 690791),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 105},
#  {'time': datetime.datetime(2024, 1, 2, 23, 30, 19, 690791),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 106},
#  {'time': datetime.datetime(2024, 1, 2, 23, 30, 19, 690791),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 107},
#  {'time': datetime.datetime(2024, 1, 2, 23, 30, 19, 690791),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 108},
#  {'time': datetime.datetime(2024, 1, 2, 23, 30, 30, 547083),
#   'event': 'body_made',
#   'wood_stock': 254,
#   'pre_paint_stock': 71},
#  {'time': datetime.datetime(2024, 1, 2, 23, 46, 7, 286638),
#   'event': 'body_made',
#   'wood_stock': 253,
#   'pre_paint_stock': 72},
#  {'time': datetime.datetime(2024, 1, 3, 0, 30, 10, 62847),
#   'event': 'neck_made',
#   'wood_stock': 252,
#   'pre_paint_stock': 74},
#  {'time': datetime.datetime(2024, 1, 3, 0, 30, 19, 690791),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 109},
#  {'time': datetime.datetime(2024, 1, 3, 0, 30, 19, 690791),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 110},
#  {'time': datetime.datetime(2024, 1, 3, 0, 30, 19, 690791),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 111},
#  {'time': datetime.datetime(2024, 1, 3, 0, 34, 10, 557778),
#   'event': 'body_made',
#   'wood_stock': 251,
#   'pre_paint_stock': 75},
#  {'time': datetime.datetime(2024, 1, 3, 0, 51, 8, 252092),
#   'event': 'body_made',
#   'wood_stock': 250,
#   'pre_paint_stock': 76},
#  {'time': datetime.datetime(2024, 1, 3, 0, 51, 44, 923824),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 112},
#  {'time': datetime.datetime(2024, 1, 3, 1, 27, 1, 563679),
#   'event': 'neck_made',
#   'wood_stock': 249,
#   'pre_paint_stock': 78},
#  {'time': datetime.datetime(2024, 1, 3, 1, 30, 19, 690791),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 113},
#  {'time': datetime.datetime(2024, 1, 3, 1, 32, 54, 815545),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 114},
#  {'time': datetime.datetime(2024, 1, 3, 1, 37, 9, 187079),
#   'event': 'body_made',
#   'wood_stock': 248,
#   'pre_paint_stock': 79},
#  {'time': datetime.datetime(2024, 1, 3, 1, 54, 18, 979300),
#   'event': 'body_made',
#   'wood_stock': 247,
#   'pre_paint_stock': 80},
#  {'time': datetime.datetime(2024, 1, 3, 2, 25, 42, 646266),
#   'event': 'painting_done',
#   'post_paint_stock': 10},
#  {'time': datetime.datetime(2024, 1, 3, 2, 36, 18, 245888),
#   'event': 'neck_made',
#   'wood_stock': 246,
#   'pre_paint_stock': 72},
#  {'time': datetime.datetime(2024, 1, 3, 2, 41, 23, 629921),
#   'event': 'body_made',
#   'wood_stock': 245,
#   'pre_paint_stock': 73},
#  {'time': datetime.datetime(2024, 1, 3, 3, 3, 35, 16736),
#   'event': 'body_made',
#   'wood_stock': 244,
#   'pre_paint_stock': 74},
#  {'time': datetime.datetime(2024, 1, 3, 3, 25, 42, 646266),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 116},
#  {'time': datetime.datetime(2024, 1, 3, 3, 25, 42, 646266),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 117},
#  {'time': datetime.datetime(2024, 1, 3, 3, 35, 35, 105138),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 118},
#  {'time': datetime.datetime(2024, 1, 3, 3, 36, 36, 446706),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 119},
#  {'time': datetime.datetime(2024, 1, 3, 3, 41, 20, 269539),
#   'event': 'neck_made',
#   'wood_stock': 243,
#   'pre_paint_stock': 76},
#  {'time': datetime.datetime(2024, 1, 3, 3, 42, 18, 773743),
#   'event': 'body_made',
#   'wood_stock': 242,
#   'pre_paint_stock': 77},
#  {'time': datetime.datetime(2024, 1, 3, 4, 0, 18, 360276),
#   'event': 'body_made',
#   'wood_stock': 241,
#   'pre_paint_stock': 78},
#  {'time': datetime.datetime(2024, 1, 3, 4, 25, 42, 646266),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 120},
#  {'time': datetime.datetime(2024, 1, 3, 4, 30, 9, 340965),
#   'event': 'neck_made',
#   'wood_stock': 240,
#   'pre_paint_stock': 80},
#  {'time': datetime.datetime(2024, 1, 3, 4, 31, 25, 810405),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 121},
#  {'time': datetime.datetime(2024, 1, 3, 4, 36, 36, 446706),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 122},
#  {'time': datetime.datetime(2024, 1, 3, 4, 42, 38, 145352),
#   'event': 'body_made',
#   'wood_stock': 239,
#   'pre_paint_stock': 81},
#  {'time': datetime.datetime(2024, 1, 3, 4, 55, 44, 631705),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 123},
#  {'time': datetime.datetime(2024, 1, 3, 5, 0, 26, 749333),
#   'event': 'body_made',
#   'wood_stock': 238,
#   'pre_paint_stock': 82},
#  {'time': datetime.datetime(2024, 1, 3, 5, 31, 25, 810405),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 124},
#  {'time': datetime.datetime(2024, 1, 3, 5, 44, 11, 952109),
#   'event': 'body_made',
#   'wood_stock': 237,
#   'pre_paint_stock': 83},
#  {'time': datetime.datetime(2024, 1, 3, 5, 50, 32, 883337),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 125},
#  {'time': datetime.datetime(2024, 1, 3, 5, 57, 59, 494799),
#   'event': 'body_made',
#   'wood_stock': 236,
#   'pre_paint_stock': 84},
#  {'time': datetime.datetime(2024, 1, 3, 5, 58, 4, 480545),
#   'event': 'neck_made',
#   'wood_stock': 235,
#   'pre_paint_stock': 86},
#  {'time': datetime.datetime(2024, 1, 3, 6, 31, 30, 811121),
#   'event': 'painting_done',
#   'post_paint_stock': 10},
#  {'time': datetime.datetime(2024, 1, 3, 6, 37, 22, 279621),
#   'event': 'body_made',
#   'wood_stock': 234,
#   'pre_paint_stock': 77},
#  {'time': datetime.datetime(2024, 1, 3, 6, 58, 41, 759991),
#   'event': 'body_made',
#   'wood_stock': 233,
#   'pre_paint_stock': 78},
#  {'time': datetime.datetime(2024, 1, 3, 7, 15, 39, 627318),
#   'event': 'neck_made',
#   'wood_stock': 232,
#   'pre_paint_stock': 80},
#  {'time': datetime.datetime(2024, 1, 3, 7, 27, 35, 663112),
#   'event': 'body_made',
#   'wood_stock': 231,
#   'pre_paint_stock': 81},
#  {'time': datetime.datetime(2024, 1, 3, 7, 31, 30, 811121),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 126},
#  {'time': datetime.datetime(2024, 1, 3, 7, 31, 30, 811121),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 127},
#  {'time': datetime.datetime(2024, 1, 3, 7, 41, 34, 844697),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 128},
#  {'time': datetime.datetime(2024, 1, 3, 7, 45, 23, 4294),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 129},
#  {'time': datetime.datetime(2024, 1, 3, 7, 59, 18, 617738),
#   'event': 'body_made',
#   'wood_stock': 230,
#   'pre_paint_stock': 82},
#  {'time': datetime.datetime(2024, 1, 3, 8, 24, 37, 95084),
#   'event': 'neck_made',
#   'wood_stock': 229,
#   'pre_paint_stock': 84},
#  {'time': datetime.datetime(2024, 1, 3, 8, 24, 58, 523252),
#   'event': 'body_made',
#   'wood_stock': 228,
#   'pre_paint_stock': 85},
#  {'time': datetime.datetime(2024, 1, 3, 8, 31, 30, 811121),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 130},
#  {'time': datetime.datetime(2024, 1, 3, 8, 33, 38, 6205),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 131},
#  {'time': datetime.datetime(2024, 1, 3, 8, 47, 32, 162890),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 132},
#  {'time': datetime.datetime(2024, 1, 3, 8, 57, 17, 756440),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 133},
#  {'time': datetime.datetime(2024, 1, 3, 9, 5, 44, 913149),
#   'event': 'body_made',
#   'wood_stock': 227,
#   'pre_paint_stock': 86},
#  {'time': datetime.datetime(2024, 1, 3, 9, 13, 2, 945406),
#   'event': 'neck_made',
#   'wood_stock': 226,
#   'pre_paint_stock': 88},
#  {'time': datetime.datetime(2024, 1, 3, 9, 18, 37, 929994),
#   'event': 'body_made',
#   'wood_stock': 225,
#   'pre_paint_stock': 89},
#  {'time': datetime.datetime(2024, 1, 3, 9, 33, 35, 911440),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 134},
#  {'time': datetime.datetime(2024, 1, 3, 9, 33, 38, 6205),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 135},
#  {'time': datetime.datetime(2024, 1, 3, 9, 57, 45, 261800),
#   'event': 'body_made',
#   'wood_stock': 224,
#   'pre_paint_stock': 90},
#  {'time': datetime.datetime(2024, 1, 3, 10, 23, 3, 684320),
#   'event': 'body_made',
#   'wood_stock': 223,
#   'pre_paint_stock': 91},
#  {'time': datetime.datetime(2024, 1, 3, 10, 27, 45, 31926),
#   'event': 'neck_made',
#   'wood_stock': 222,
#   'pre_paint_stock': 93},
#  {'time': datetime.datetime(2024, 1, 3, 10, 54, 33, 317311),
#   'event': 'painting_done',
#   'post_paint_stock': 10},
#  {'time': datetime.datetime(2024, 1, 3, 10, 59, 11, 383251),
#   'event': 'body_made',
#   'wood_stock': 221,
#   'pre_paint_stock': 84},
#  {'time': datetime.datetime(2024, 1, 3, 11, 27, 47, 518326),
#   'event': 'neck_made',
#   'wood_stock': 220,
#   'pre_paint_stock': 86},
#  {'time': datetime.datetime(2024, 1, 3, 11, 30, 53, 809698),
#   'event': 'body_made',
#   'wood_stock': 219,
#   'pre_paint_stock': 87},
#  {'time': datetime.datetime(2024, 1, 3, 11, 58, 34, 615857),
#   'event': 'body_made',
#   'wood_stock': 218,
#   'pre_paint_stock': 88},
#  {'time': datetime.datetime(2024, 1, 3, 12, 0, 19, 778379),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 137},
#  {'time': datetime.datetime(2024, 1, 3, 12, 3, 40, 430590),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 138},
#  {'time': datetime.datetime(2024, 1, 3, 12, 6, 34, 402091),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 139},
#  {'time': datetime.datetime(2024, 1, 3, 12, 9, 45, 41443),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 140},
#  {'time': datetime.datetime(2024, 1, 3, 12, 24, 36, 98729),
#   'event': 'neck_made',
#   'wood_stock': 217,
#   'pre_paint_stock': 90},
#  {'time': datetime.datetime(2024, 1, 3, 12, 31, 23, 986812),
#   'event': 'body_made',
#   'wood_stock': 216,
#   'pre_paint_stock': 91},
#  {'time': datetime.datetime(2024, 1, 3, 12, 59, 0, 541724),
#   'event': 'body_made',
#   'wood_stock': 215,
#   'pre_paint_stock': 92},
#  {'time': datetime.datetime(2024, 1, 3, 13, 0, 19, 778379),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 141},
#  {'time': datetime.datetime(2024, 1, 3, 13, 6, 34, 402091),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 142},
#  {'time': datetime.datetime(2024, 1, 3, 13, 14, 54, 549195),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 143},
#  {'time': datetime.datetime(2024, 1, 3, 13, 15, 49, 991992),
#   'event': 'neck_made',
#   'wood_stock': 214,
#   'pre_paint_stock': 94},
#  {'time': datetime.datetime(2024, 1, 3, 13, 18, 48, 343045),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 144},
#  {'time': datetime.datetime(2024, 1, 3, 13, 39, 38, 22923),
#   'event': 'body_made',
#   'wood_stock': 213,
#   'pre_paint_stock': 95},
#  {'time': datetime.datetime(2024, 1, 3, 13, 59, 1, 529494),
#   'event': 'body_made',
#   'wood_stock': 212,
#   'pre_paint_stock': 96},
#  {'time': datetime.datetime(2024, 1, 3, 14, 0, 19, 778379),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 145},
#  {'time': datetime.datetime(2024, 1, 3, 14, 18, 53, 461362),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 146},
#  {'time': datetime.datetime(2024, 1, 3, 14, 23, 15, 309141),
#   'event': 'neck_made',
#   'wood_stock': 211,
#   'pre_paint_stock': 98},
#  {'time': datetime.datetime(2024, 1, 3, 14, 37, 8, 63989),
#   'event': 'body_made',
#   'wood_stock': 210,
#   'pre_paint_stock': 99},
#  {'time': datetime.datetime(2024, 1, 3, 14, 53, 36, 781614),
#   'event': 'body_made',
#   'wood_stock': 209,
#   'pre_paint_stock': 100},
#  {'time': datetime.datetime(2024, 1, 3, 15, 5, 37, 939152),
#   'event': 'painting_done',
#   'post_paint_stock': 10},
#  {'time': datetime.datetime(2024, 1, 3, 15, 7, 2, 30867),
#   'event': 'neck_made',
#   'wood_stock': 208,
#   'pre_paint_stock': 92},
#  {'time': datetime.datetime(2024, 1, 3, 15, 44, 25, 943436),
#   'event': 'body_made',
#   'wood_stock': 207,
#   'pre_paint_stock': 93},
#  {'time': datetime.datetime(2024, 1, 3, 15, 45, 58, 625624),
#   'event': 'body_made',
#   'wood_stock': 206,
#   'pre_paint_stock': 94},
#  {'time': datetime.datetime(2024, 1, 3, 16, 5, 37, 939152),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 147},
#  {'time': datetime.datetime(2024, 1, 3, 16, 5, 37, 939152),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 148},
#  {'time': datetime.datetime(2024, 1, 3, 16, 8, 1, 987071),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 149},
#  {'time': datetime.datetime(2024, 1, 3, 16, 15, 24, 431064),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 150},
#  {'time': datetime.datetime(2024, 1, 3, 16, 17, 0, 883746),
#   'event': 'neck_made',
#   'wood_stock': 205,
#   'pre_paint_stock': 96},
#  {'time': datetime.datetime(2024, 1, 3, 16, 37, 13, 458167),
#   'event': 'body_made',
#   'wood_stock': 204,
#   'pre_paint_stock': 97},
#  {'time': datetime.datetime(2024, 1, 3, 16, 44, 4, 338116),
#   'event': 'body_made',
#   'wood_stock': 203,
#   'pre_paint_stock': 98},
#  {'time': datetime.datetime(2024, 1, 3, 17, 5, 37, 939152),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 151},
#  {'time': datetime.datetime(2024, 1, 3, 17, 10, 49, 676110),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 152},
#  {'time': datetime.datetime(2024, 1, 3, 17, 15, 24, 431064),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 153},
#  {'time': datetime.datetime(2024, 1, 3, 17, 15, 37, 176497),
#   'event': 'neck_made',
#   'wood_stock': 202,
#   'pre_paint_stock': 100},
#  {'time': datetime.datetime(2024, 1, 3, 17, 16, 47, 399290),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 154},
#  {'time': datetime.datetime(2024, 1, 3, 17, 45, 12, 304442),
#   'event': 'body_made',
#   'wood_stock': 201,
#   'pre_paint_stock': 100},
#  {'time': datetime.datetime(2024, 1, 3, 17, 47, 33, 388894),
#   'event': 'body_made',
#   'wood_stock': 200,
#   'pre_paint_stock': 100},
#  {'time': datetime.datetime(2024, 1, 3, 18, 5, 43, 224037),
#   'event': 'neck_made',
#   'wood_stock': 199,
#   'pre_paint_stock': 100},
#  {'time': datetime.datetime(2024, 1, 3, 18, 10, 49, 676110),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 155},
#  {'time': datetime.datetime(2024, 1, 3, 18, 11, 1, 235301),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 156},
#  {'time': datetime.datetime(2024, 1, 3, 18, 39, 22, 359531),
#   'event': 'body_made',
#   'wood_stock': 198,
#   'pre_paint_stock': 100},
#  {'time': datetime.datetime(2024, 1, 3, 18, 40, 17, 354275),
#   'event': 'body_made',
#   'wood_stock': 197,
#   'pre_paint_stock': 100},
#  {'time': datetime.datetime(2024, 1, 3, 19, 6, 58, 10820),
#   'event': 'neck_made',
#   'wood_stock': 196,
#   'pre_paint_stock': 100},
#  {'time': datetime.datetime(2024, 1, 3, 19, 9, 50, 479494),
#   'event': 'painting_done',
#   'post_paint_stock': 10},
#  {'time': datetime.datetime(2024, 1, 3, 19, 40, 48, 323209),
#   'event': 'body_made',
#   'wood_stock': 195,
#   'pre_paint_stock': 99},
#  {'time': datetime.datetime(2024, 1, 3, 19, 47, 57, 896082),
#   'event': 'body_made',
#   'wood_stock': 194,
#   'pre_paint_stock': 100},
#  {'time': datetime.datetime(2024, 1, 3, 20, 9, 50, 479494),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 157},
#  {'time': datetime.datetime(2024, 1, 3, 20, 9, 50, 479494),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 158},
#  {'time': datetime.datetime(2024, 1, 3, 20, 9, 50, 479494),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 159},
#  {'time': datetime.datetime(2024, 1, 3, 20, 12, 34, 94357),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 160},
#  {'time': datetime.datetime(2024, 1, 3, 20, 15, 8, 104590),
#   'event': 'neck_made',
#   'wood_stock': 193,
#   'pre_paint_stock': 100},
#  {'time': datetime.datetime(2024, 1, 3, 20, 40, 53, 102382),
#   'event': 'body_made',
#   'wood_stock': 192,
#   'pre_paint_stock': 100},
#  {'time': datetime.datetime(2024, 1, 3, 20, 43, 17, 662240),
#   'event': 'body_made',
#   'wood_stock': 191,
#   'pre_paint_stock': 100},
#  {'time': datetime.datetime(2024, 1, 3, 21, 9, 50, 479494),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 161},
#  {'time': datetime.datetime(2024, 1, 3, 21, 9, 50, 479494),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 162},
#  {'time': datetime.datetime(2024, 1, 3, 21, 12, 0, 178226),
#   'event': 'neck_made',
#   'wood_stock': 190,
#   'pre_paint_stock': 100},
#  {'time': datetime.datetime(2024, 1, 3, 21, 12, 34, 94357),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 163},
#  {'time': datetime.datetime(2024, 1, 3, 21, 13, 26, 510588),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 164},
#  {'time': datetime.datetime(2024, 1, 3, 21, 33, 11, 216963),
#   'event': 'body_made',
#   'wood_stock': 189,
#   'pre_paint_stock': 100},
#  {'time': datetime.datetime(2024, 1, 3, 21, 51, 35, 400120),
#   'event': 'body_made',
#   'wood_stock': 188,
#   'pre_paint_stock': 100},
#  {'time': datetime.datetime(2024, 1, 3, 22, 9, 50, 479494),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 166},
#  {'time': datetime.datetime(2024, 1, 3, 22, 14, 39, 693142),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 167},
# ...
#   'event': 'body_made',
#   'wood_stock': 106,
#   'pre_paint_stock': 99},
#  {'time': datetime.datetime(2024, 1, 5, 1, 46, 9, 22383),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 234},
#  {'time': datetime.datetime(2024, 1, 5, 1, 46, 15, 272516),
#   'event': 'neck_made',
#   'wood_stock': 105,
#   'pre_paint_stock': 99},
#  {'time': datetime.datetime(2024, 1, 5, 1, 52, 16, 769789),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 235},
#  {'time': datetime.datetime(2024, 1, 5, 1, 58, 26, 82227),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 236},
#  {'time': datetime.datetime(2024, 1, 5, 2, 6, 25, 367093),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 237},
#  {'time': datetime.datetime(2024, 1, 5, 2, 12, 49, 939683),
#   'event': 'body_made',
#   'wood_stock': 104,
#   'pre_paint_stock': 99},
#  {'time': datetime.datetime(2024, 1, 5, 2, 27, 39, 133036),
#   'event': 'neck_made',
#   'wood_stock': 103,
#   'pre_paint_stock': 99},
#  {'time': datetime.datetime(2024, 1, 5, 2, 30, 24, 158012),
#   'event': 'body_made',
#   'wood_stock': 102,
#   'pre_paint_stock': 99},
#  {'time': datetime.datetime(2024, 1, 5, 2, 46, 9, 22383),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 238},
#  {'time': datetime.datetime(2024, 1, 5, 2, 52, 16, 769789),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 239},
#  {'time': datetime.datetime(2024, 1, 5, 3, 17, 12, 700400),
#   'event': 'body_made',
#   'wood_stock': 101,
#   'pre_paint_stock': 99},
#  {'time': datetime.datetime(2024, 1, 5, 3, 25, 9, 807409),
#   'event': 'body_made',
#   'wood_stock': 100,
#   'pre_paint_stock': 99},
#  {'time': datetime.datetime(2024, 1, 5, 3, 49, 24, 661347),
#   'event': 'neck_made',
#   'wood_stock': 99,
#   'pre_paint_stock': 99},
#  {'time': datetime.datetime(2024, 1, 5, 3, 59, 19, 920023),
#   'event': 'painting_done',
#   'post_paint_stock': 10},
#  {'time': datetime.datetime(2024, 1, 5, 4, 16, 5, 43755),
#   'event': 'body_made',
#   'wood_stock': 98,
#   'pre_paint_stock': 100},
#  {'time': datetime.datetime(2024, 1, 5, 4, 26, 54, 562069),
#   'event': 'body_made',
#   'wood_stock': 97,
#   'pre_paint_stock': 100},
#  {'time': datetime.datetime(2024, 1, 5, 4, 45, 48, 331506),
#   'event': 'neck_made',
#   'wood_stock': 96,
#   'pre_paint_stock': 100},
#  {'time': datetime.datetime(2024, 1, 5, 4, 59, 19, 920023),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 241},
#  {'time': datetime.datetime(2024, 1, 5, 4, 59, 19, 920023),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 242},
#  {'time': datetime.datetime(2024, 1, 5, 5, 6, 37, 167435),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 243},
#  {'time': datetime.datetime(2024, 1, 5, 5, 7, 32, 480240),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 244},
#  {'time': datetime.datetime(2024, 1, 5, 5, 23, 52, 453276),
#   'event': 'body_made',
#   'wood_stock': 95,
#   'pre_paint_stock': 100},
#  {'time': datetime.datetime(2024, 1, 5, 5, 27, 45, 627800),
#   'event': 'neck_made',
#   'wood_stock': 94,
#   'pre_paint_stock': 100},
#  {'time': datetime.datetime(2024, 1, 5, 5, 38, 16, 401984),
#   'event': 'body_made',
#   'wood_stock': 93,
#   'pre_paint_stock': 100},
#  {'time': datetime.datetime(2024, 1, 5, 5, 59, 19, 920023),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 245},
#  {'time': datetime.datetime(2024, 1, 5, 5, 59, 19, 920023),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 246},
#  {'time': datetime.datetime(2024, 1, 5, 6, 6, 37, 167435),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 247},
#  {'time': datetime.datetime(2024, 1, 5, 6, 10, 31, 203536),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 248},
#  {'time': datetime.datetime(2024, 1, 5, 6, 10, 37, 88349),
#   'event': 'neck_made',
#   'wood_stock': 92,
#   'pre_paint_stock': 100},
#  {'time': datetime.datetime(2024, 1, 5, 6, 19, 23, 701684),
#   'event': 'body_made',
#   'wood_stock': 91,
#   'pre_paint_stock': 100},
#  {'time': datetime.datetime(2024, 1, 5, 6, 33, 45, 100034),
#   'event': 'body_made',
#   'wood_stock': 90,
#   'pre_paint_stock': 100},
#  {'time': datetime.datetime(2024, 1, 5, 6, 59, 19, 920023),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 249},
#  {'time': datetime.datetime(2024, 1, 5, 7, 9, 12, 272189),
#   'event': 'neck_made',
#   'wood_stock': 89,
#   'pre_paint_stock': 100},
#  {'time': datetime.datetime(2024, 1, 5, 7, 13, 8, 624415),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 250},
#  {'time': datetime.datetime(2024, 1, 5, 7, 18, 42, 490014),
#   'event': 'body_made',
#   'wood_stock': 88,
#   'pre_paint_stock': 100},
#  {'time': datetime.datetime(2024, 1, 5, 7, 26, 7, 60761),
#   'event': 'body_made',
#   'wood_stock': 87,
#   'pre_paint_stock': 100},
#  {'time': datetime.datetime(2024, 1, 5, 7, 49, 0, 977292),
#   'event': 'painting_done',
#   'post_paint_stock': 10},
#  {'time': datetime.datetime(2024, 1, 5, 8, 11, 52, 623677),
#   'event': 'neck_made',
#   'wood_stock': 86,
#   'pre_paint_stock': 99},
#  {'time': datetime.datetime(2024, 1, 5, 8, 25, 9, 670555),
#   'event': 'body_made',
#   'wood_stock': 85,
#   'pre_paint_stock': 99},
#  {'time': datetime.datetime(2024, 1, 5, 8, 26, 25, 871961),
#   'event': 'body_made',
#   'wood_stock': 84,
#   'pre_paint_stock': 99},
#  {'time': datetime.datetime(2024, 1, 5, 8, 49, 0, 977292),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 251},
#  {'time': datetime.datetime(2024, 1, 5, 8, 49, 0, 977292),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 252},
#  {'time': datetime.datetime(2024, 1, 5, 8, 50, 5, 486888),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 253},
#  {'time': datetime.datetime(2024, 1, 5, 8, 51, 27, 668781),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 254},
#  {'time': datetime.datetime(2024, 1, 5, 9, 18, 25, 99615),
#   'event': 'body_made',
#   'wood_stock': 83,
#   'pre_paint_stock': 99},
#  {'time': datetime.datetime(2024, 1, 5, 9, 20, 57, 68455),
#   'event': 'neck_made',
#   'wood_stock': 82,
#   'pre_paint_stock': 99},
#  {'time': datetime.datetime(2024, 1, 5, 9, 22, 53, 177958),
#   'event': 'body_made',
#   'wood_stock': 81,
#   'pre_paint_stock': 99},
#  {'time': datetime.datetime(2024, 1, 5, 9, 49, 0, 977292),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 255},
#  {'time': datetime.datetime(2024, 1, 5, 9, 50, 5, 486888),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 256},
#  {'time': datetime.datetime(2024, 1, 5, 9, 51, 27, 668781),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 257},
#  {'time': datetime.datetime(2024, 1, 5, 9, 56, 6, 402107),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 258},
#  {'time': datetime.datetime(2024, 1, 5, 10, 6, 56, 89110),
#   'event': 'neck_made',
#   'wood_stock': 80,
#   'pre_paint_stock': 99},
#  {'time': datetime.datetime(2024, 1, 5, 10, 21, 50, 542335),
#   'event': 'body_made',
#   'wood_stock': 79,
#   'pre_paint_stock': 99},
#  {'time': datetime.datetime(2024, 1, 5, 10, 33, 26, 934886),
#   'event': 'body_made',
#   'wood_stock': 78,
#   'pre_paint_stock': 99},
#  {'time': datetime.datetime(2024, 1, 5, 10, 49, 0, 977292),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 259},
#  {'time': datetime.datetime(2024, 1, 5, 10, 50, 55, 119796),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 260},
#  {'time': datetime.datetime(2024, 1, 5, 11, 8, 38, 210181),
#   'event': 'neck_made',
#   'wood_stock': 77,
#   'pre_paint_stock': 99},
#  {'time': datetime.datetime(2024, 1, 5, 11, 18, 2, 386855),
#   'event': 'body_made',
#   'wood_stock': 76,
#   'pre_paint_stock': 99},
#  {'time': datetime.datetime(2024, 1, 5, 11, 30, 13, 73284),
#   'event': 'body_made',
#   'wood_stock': 75,
#   'pre_paint_stock': 99},
#  {'time': datetime.datetime(2024, 1, 5, 11, 59, 44, 575507),
#   'event': 'painting_done',
#   'post_paint_stock': 10},
#  {'time': datetime.datetime(2024, 1, 5, 12, 2, 58, 864318),
#   'event': 'neck_made',
#   'wood_stock': 74,
#   'pre_paint_stock': 100},
#  {'time': datetime.datetime(2024, 1, 5, 12, 29, 20, 273455),
#   'event': 'body_made',
#   'wood_stock': 73,
#   'pre_paint_stock': 100},
#  {'time': datetime.datetime(2024, 1, 5, 12, 31, 7, 878828),
#   'event': 'body_made',
#   'wood_stock': 72,
#   'pre_paint_stock': 100},
#  {'time': datetime.datetime(2024, 1, 5, 12, 59, 44, 575507),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 261},
#  {'time': datetime.datetime(2024, 1, 5, 12, 59, 44, 575507),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 262},
#  {'time': datetime.datetime(2024, 1, 5, 12, 59, 44, 575507),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 263},
#  {'time': datetime.datetime(2024, 1, 5, 12, 59, 44, 575507),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 264},
#  {'time': datetime.datetime(2024, 1, 5, 13, 20, 32, 918551),
#   'event': 'neck_made',
#   'wood_stock': 71,
#   'pre_paint_stock': 100},
#  {'time': datetime.datetime(2024, 1, 5, 13, 35, 27, 345014),
#   'event': 'body_made',
#   'wood_stock': 70,
#   'pre_paint_stock': 100},
#  {'time': datetime.datetime(2024, 1, 5, 13, 46, 16, 494580),
#   'event': 'body_made',
#   'wood_stock': 69,
#   'pre_paint_stock': 100},
#  {'time': datetime.datetime(2024, 1, 5, 13, 59, 44, 575507),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 265},
#  {'time': datetime.datetime(2024, 1, 5, 14, 0, 45, 68922),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 267},
#  {'time': datetime.datetime(2024, 1, 5, 14, 5, 36, 622464),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 268},
#  {'time': datetime.datetime(2024, 1, 5, 14, 8, 35, 602940),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 269},
#  {'time': datetime.datetime(2024, 1, 5, 14, 39, 17, 795157),
#   'event': 'neck_made',
#   'wood_stock': 68,
#   'pre_paint_stock': 100},
#  {'time': datetime.datetime(2024, 1, 5, 14, 43, 59, 289217),
#   'event': 'body_made',
#   'wood_stock': 67,
#   'pre_paint_stock': 100},
#  {'time': datetime.datetime(2024, 1, 5, 14, 44, 47, 14319),
#   'event': 'body_made',
#   'wood_stock': 66,
#   'pre_paint_stock': 100},
#  {'time': datetime.datetime(2024, 1, 5, 15, 0, 45, 68922),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 270},
#  {'time': datetime.datetime(2024, 1, 5, 15, 7, 2, 243608),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 271},
#  {'time': datetime.datetime(2024, 1, 5, 15, 45, 53, 27064),
#   'event': 'neck_made',
#   'wood_stock': 65,
#   'pre_paint_stock': 100},
#  {'time': datetime.datetime(2024, 1, 5, 15, 48, 45, 251927),
#   'event': 'body_made',
#   'wood_stock': 64,
#   'pre_paint_stock': 100},
#  {'time': datetime.datetime(2024, 1, 5, 15, 54, 52, 598302),
#   'event': 'body_made',
#   'wood_stock': 63,
#   'pre_paint_stock': 100},
#  {'time': datetime.datetime(2024, 1, 5, 16, 19, 8, 691412),
#   'event': 'painting_done',
#   'post_paint_stock': 10},
#  {'time': datetime.datetime(2024, 1, 5, 16, 48, 15, 966481),
#   'event': 'body_made',
#   'wood_stock': 62,
#   'pre_paint_stock': 99},
#  {'time': datetime.datetime(2024, 1, 5, 16, 54, 51, 196399),
#   'event': 'body_made',
#   'wood_stock': 61,
#   'pre_paint_stock': 99},
#  {'time': datetime.datetime(2024, 1, 5, 17, 4, 51, 503479),
#   'event': 'neck_made',
#   'wood_stock': 60,
#   'pre_paint_stock': 99},
#  {'time': datetime.datetime(2024, 1, 5, 17, 19, 8, 691412),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 272},
#  {'time': datetime.datetime(2024, 1, 5, 17, 19, 8, 691412),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 273},
#  {'time': datetime.datetime(2024, 1, 5, 17, 19, 8, 691412),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 274},
#  {'time': datetime.datetime(2024, 1, 5, 17, 39, 5, 883035),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 275},
#  {'time': datetime.datetime(2024, 1, 5, 17, 49, 50, 230491),
#   'event': 'body_made',
#   'wood_stock': 59,
#   'pre_paint_stock': 99},
#  {'time': datetime.datetime(2024, 1, 5, 17, 51, 29, 7976),
#   'event': 'body_made',
#   'wood_stock': 58,
#   'pre_paint_stock': 99},
#  {'time': datetime.datetime(2024, 1, 5, 18, 11, 41, 939304),
#   'event': 'neck_made',
#   'wood_stock': 57,
#   'pre_paint_stock': 99},
#  {'time': datetime.datetime(2024, 1, 5, 18, 20, 55, 715806),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 276},
#  {'time': datetime.datetime(2024, 1, 5, 18, 25, 56, 518267),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 277},
#  {'time': datetime.datetime(2024, 1, 5, 18, 31, 7, 236541),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 278},
#  {'time': datetime.datetime(2024, 1, 5, 18, 46, 23, 510893),
#   'event': 'neck_made',
#   'wood_stock': 56,
#   'pre_paint_stock': 99},
#  {'time': datetime.datetime(2024, 1, 5, 18, 46, 36, 618920),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 279},
#  {'time': datetime.datetime(2024, 1, 5, 18, 48, 59, 411172),
#   'event': 'body_made',
#   'wood_stock': 55,
#   'pre_paint_stock': 99},
#  {'time': datetime.datetime(2024, 1, 5, 19, 1, 26, 176527),
#   'event': 'body_made',
#   'wood_stock': 54,
#   'pre_paint_stock': 99},
#  {'time': datetime.datetime(2024, 1, 5, 19, 21, 53, 280933),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 280},
#  {'time': datetime.datetime(2024, 1, 5, 19, 35, 4, 383920),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 281},
#  {'time': datetime.datetime(2024, 1, 5, 19, 37, 55, 746914),
#   'event': 'neck_made',
#   'wood_stock': 53,
#   'pre_paint_stock': 99},
#  {'time': datetime.datetime(2024, 1, 5, 19, 45, 51, 105972),
#   'event': 'body_made',
#   'wood_stock': 52,
#   'pre_paint_stock': 99},
#  {'time': datetime.datetime(2024, 1, 5, 20, 10, 29, 667500),
#   'event': 'body_made',
#   'wood_stock': 51,
#   'pre_paint_stock': 99},
#  {'time': datetime.datetime(2024, 1, 5, 20, 15, 25, 928131),
#   'event': 'painting_done',
#   'post_paint_stock': 10},
#  {'time': datetime.datetime(2024, 1, 5, 20, 36, 36, 698702),
#   'event': 'neck_made',
#   'wood_stock': 50,
#   'pre_paint_stock': 100},
#  {'time': datetime.datetime(2024, 1, 5, 20, 37, 56, 655300),
#   'event': 'body_made',
#   'wood_stock': 49,
#   'pre_paint_stock': 100},
#  {'time': datetime.datetime(2024, 1, 5, 21, 13, 18, 888330),
#   'event': 'body_made',
#   'wood_stock': 48,
#   'pre_paint_stock': 100},
#  {'time': datetime.datetime(2024, 1, 5, 21, 15, 25, 928131),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 282},
#  {'time': datetime.datetime(2024, 1, 5, 21, 15, 25, 928131),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 283},
#  {'time': datetime.datetime(2024, 1, 5, 21, 15, 25, 928131),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 284},
#  {'time': datetime.datetime(2024, 1, 5, 21, 15, 25, 928131),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 285},
#  {'time': datetime.datetime(2024, 1, 5, 21, 41, 37, 747254),
#   'event': 'body_made',
#   'wood_stock': 47,
#   'pre_paint_stock': 100},
#  {'time': datetime.datetime(2024, 1, 5, 21, 53, 29, 857260),
#   'event': 'neck_made',
#   'wood_stock': 46,
#   'pre_paint_stock': 100},
#  {'time': datetime.datetime(2024, 1, 5, 21, 56, 55, 751723),
#   'event': 'body_made',
#   'wood_stock': 45,
#   'pre_paint_stock': 100},
#  {'time': datetime.datetime(2024, 1, 5, 22, 15, 25, 928131),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 286},
#  {'time': datetime.datetime(2024, 1, 5, 22, 21, 48, 378484),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 287},
#  {'time': datetime.datetime(2024, 1, 5, 22, 22, 37, 808090),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 288},
#  {'time': datetime.datetime(2024, 1, 5, 22, 27, 55, 837403),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 289},
#  {'time': datetime.datetime(2024, 1, 5, 22, 41, 14, 564092),
#   'event': 'body_made',
#   'wood_stock': 44,
#   'pre_paint_stock': 100},
#  {'time': datetime.datetime(2024, 1, 5, 22, 56, 24, 220935),
#   'event': 'body_made',
#   'wood_stock': 43,
#   'pre_paint_stock': 100},
#  {'time': datetime.datetime(2024, 1, 5, 23, 2, 45, 683145),
#   'event': 'neck_made',
#   'wood_stock': 42,
#   'pre_paint_stock': 100},
#  {'time': datetime.datetime(2024, 1, 5, 23, 16, 55, 905653),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 290},
#  {'time': datetime.datetime(2024, 1, 5, 23, 21, 48, 378484),
#   'event': 'guitar_assembled',
#   'dispatch_stock': 291},
#  {'time': datetime.datetime(2024, 1, 5, 23, 49, 27, 485691),
#   'event': 'body_made',
#   'wood_stock': 41,
#   'pre_paint_stock': 100},
#  {'time': datetime.datetime(2024, 1, 5, 23, 50, 24, 196184),
#   'event': 'body_made',
#   'wood_stock': 40,
#   'pre_paint_stock': 100},
#  {'time': datetime.datetime(2024, 1, 5, 23, 56, 30, 264777),
#   'event': 'neck_made',
#   'wood_stock': 39,
#   'pre_paint_stock': 100}]

# %%
# Salvar logs em DataFrame
logs_df = pd.DataFrame(logs)
logs_df.to_csv('production_logs.csv', index=False)
logs_df.tail(50)
# Out:
#                           time             event  wood_stock  pre_paint_stock  \
# 617 2024-01-05 15:07:02.243608  guitar_assembled         NaN              NaN
# 618 2024-01-05 15:45:53.027064         neck_made        65.0            100.0
# 619 2024-01-05 15:48:45.251927         body_made        64.0            100.0
# 620 2024-01-05 15:54:52.598302         body_made        63.0            100.0
# 621 2024-01-05 16:19:08.691412     painting_done         NaN              NaN
# 622 2024-01-05 16:48:15.966481         body_made        62.0             99.0
# 623 2024-01-05 16:54:51.196399         body_made        61.0             99.0
# 624 2024-01-05 17:04:51.503479         neck_made        60.0             99.0
# 625 2024-01-05 17:19:08.691412  guitar_assembled         NaN              NaN
# 626 2024-01-05 17:19:08.691412  guitar_assembled         NaN              NaN
# 627 2024-01-05 17:19:08.691412  guitar_assembled         NaN              NaN
# 628 2024-01-05 17:39:05.883035  guitar_assembled         NaN              NaN
# 629 2024-01-05 17:49:50.230491         body_made        59.0             99.0
# 630 2024-01-05 17:51:29.007976         body_made        58.0             99.0
# 631 2024-01-05 18:11:41.939304         neck_made        57.0             99.0
# 632 2024-01-05 18:20:55.715806  guitar_assembled         NaN              NaN
# 633 2024-01-05 18:25:56.518267  guitar_assembled         NaN              NaN
# 634 2024-01-05 18:31:07.236541  guitar_assembled         NaN              NaN
# 635 2024-01-05 18:46:23.510893         neck_made        56.0             99.0
# 636 2024-01-05 18:46:36.618920  guitar_assembled         NaN              NaN
# 637 2024-01-05 18:48:59.411172         body_made        55.0             99.0
# 638 2024-01-05 19:01:26.176527         body_made        54.0             99.0
# 639 2024-01-05 19:21:53.280933  guitar_assembled         NaN              NaN
# 640 2024-01-05 19:35:04.383920  guitar_assembled         NaN              NaN
# 641 2024-01-05 19:37:55.746914         neck_made        53.0             99.0
# 642 2024-01-05 19:45:51.105972         body_made        52.0             99.0
# 643 2024-01-05 20:10:29.667500         body_made        51.0             99.0
# 644 2024-01-05 20:15:25.928131     painting_done         NaN              NaN
# 645 2024-01-05 20:36:36.698702         neck_made        50.0            100.0
# 646 2024-01-05 20:37:56.655300         body_made        49.0            100.0
# 647 2024-01-05 21:13:18.888330         body_made        48.0            100.0
# 648 2024-01-05 21:15:25.928131  guitar_assembled         NaN              NaN
# 649 2024-01-05 21:15:25.928131  guitar_assembled         NaN              NaN
# 650 2024-01-05 21:15:25.928131  guitar_assembled         NaN              NaN
# 651 2024-01-05 21:15:25.928131  guitar_assembled         NaN              NaN
# 652 2024-01-05 21:41:37.747254         body_made        47.0            100.0
# 653 2024-01-05 21:53:29.857260         neck_made        46.0            100.0
# 654 2024-01-05 21:56:55.751723         body_made        45.0            100.0
# 655 2024-01-05 22:15:25.928131  guitar_assembled         NaN              NaN
# 656 2024-01-05 22:21:48.378484  guitar_assembled         NaN              NaN
# 657 2024-01-05 22:22:37.808090  guitar_assembled         NaN              NaN
# 658 2024-01-05 22:27:55.837403  guitar_assembled         NaN              NaN
# 659 2024-01-05 22:41:14.564092         body_made        44.0            100.0
# 660 2024-01-05 22:56:24.220935         body_made        43.0            100.0
# 661 2024-01-05 23:02:45.683145         neck_made        42.0            100.0
# 662 2024-01-05 23:16:55.905653  guitar_assembled         NaN              NaN
# 663 2024-01-05 23:21:48.378484  guitar_assembled         NaN              NaN
# 664 2024-01-05 23:49:27.485691         body_made        41.0            100.0
# 665 2024-01-05 23:50:24.196184         body_made        40.0            100.0
# 666 2024-01-05 23:56:30.264777         neck_made        39.0            100.0
#
#      post_paint_stock  dispatch_stock
# 617               NaN           271.0
# 618               NaN             NaN
# 619               NaN             NaN
# 620               NaN             NaN
# 621              10.0             NaN
# 622               NaN             NaN
# 623               NaN             NaN
# 624               NaN             NaN
# 625               NaN           272.0
# 626               NaN           273.0
# 627               NaN           274.0
# 628               NaN           275.0
# 629               NaN             NaN
# 630               NaN             NaN
# 631               NaN             NaN
# 632               NaN           276.0
# 633               NaN           277.0
# 634               NaN           278.0
# 635               NaN             NaN
# 636               NaN           279.0
# 637               NaN             NaN
# 638               NaN             NaN
# 639               NaN           280.0
# 640               NaN           281.0
# 641               NaN             NaN
# 642               NaN             NaN
# 643               NaN             NaN
# 644              10.0             NaN
# 645               NaN             NaN
# 646               NaN             NaN
# 647               NaN             NaN
# 648               NaN           282.0
# 649               NaN           283.0
# 650               NaN           284.0
# 651               NaN           285.0
# 652               NaN             NaN
# 653               NaN             NaN
# 654               NaN             NaN
# 655               NaN           286.0
# 656               NaN           287.0
# 657               NaN           288.0
# 658               NaN           289.0
# 659               NaN             NaN
# 660               NaN             NaN
# 661               NaN             NaN
# 662               NaN           290.0
# 663               NaN           291.0
# 664               NaN             NaN
# 665               NaN             NaN
# 666               NaN             NaN

# %%
((1.96/2)*(1/0.05))**2
# Out:
# 384.1600000000001

# %%
384.1600000000001*(0.5**2)
# Out:
# 96.04000000000002
